# %% [markdown]
# <a href="https://colab.research.google.com/github/Hafy-hafiz/numpy/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# This is a Pythn code to print hy

# %%
print('hy')
# Out:
# hy
